# %% [markdown]
# #Functions

# %% [markdown]
# #1.What is the difference between a function and a method in python?
#  - In python, the difference between a function and a method is primarily based on how they are defined and where they are used:
#
# 1. Functions:
#
#   - A function is a block of code that performs a specific task and can be called by its name.
#   - Functions are typically defined using the def keyword outside of any class.
#   - Functions can be called independently.

# %%
#Example of Function

def greet(name):
      return f"Hello,{name}!"
      Print(greet("Alice"))

# %% [markdown]
# #2.Method:
# - A method is a function that is associated with an object and is defined within a class.
# - Method are always called on an instance of a class
# (or the class itself in the case of class methods).

# %%
# example of Methods:
class Greeter:
  def greet(self,name):
    return f"Hello, {name}!"

    greeter=Greeter()
    print(greeter.greet("Bob"))

# %% [markdown]
# Explanation: A function is standalone, while a method is a function that is bound to an object or class. ,Method are called using  the dot notation on instances or classes.

# %% [markdown]
# #2.Explain the concept of function arguments and parameters in python.
#  - In Python, parameters are placeholders defined in a function's definition, while arguments are the actual values passed to the function when it,s called.
#
# #Parameters
# - Parametrs are variables that are listed inside the paraenthesis of a function definition.
# - They act as placeholders to recieve values from the the function call.
# #Example:
#    - In the function

# %%
def greet(name,greeting): #name,and greeting are parameters.
    pass

# %% [markdown]
# # Arguments
# - Arguments are the values that are passed to the function when it is called.
# -They provide the actual data that the functioin will work with.
# #Example
# -In the function call

# %%
def greet(arg1, arg2): #"arg1" and "arg2" are arguments.
    pass

# %% [markdown]
# #3. What are the different ways to define and call a function in Python?
# -In Python, we can define and call functions in several ways depending on the use case. Here's a breakdown of the most common ones:
# # 1. Standard Function Definition:
# Using the def keyword.

# %%
def greet(name):
  return f"Hello,{name}!"

  # Calling the function

print(greet("Alice"))

# %% [markdown]
# #2. Lambda (Anonymous) Functions
#   - Used for short, single-expression function.

# %%
square=lambda x:x**2
print(square(5))

# %% [markdown]
# #3.Recursive Functions
# -Functions that call themselves.

# %%
def factorial(n):
  if n==0:
    return 1
  else:
    return n*factorial(n-1)
print(factorial(5))

# %% [markdown]
# #4.Functions as first-class Objects
# -Functions can be passed as arguments, returned from other functions, and assigned to variables.

# %%
def add(x,y):
  return x+y
  def operate(fun,a,b):
    return func(a,b)

    print(operate(add,3,4))

# %% [markdown]
# Similarly we can use many several ways to define and call a function in python.

# %% [markdown]
# #4.What is the purpose of the 'return' statement in a python function?
# # Purpose of the 'return' statement in a python function:
# -The return statement in a Python function serves two main purposes:
# #1. To send a Result Back to the Caller
# -It ends the function and optionally sends a value back to wherever the function was called.

# %%
def add(a,b):
    return a+b

result=add(3,4)
print(result)

# %% [markdown]
# #2. To Exit the Function Early
# - We can use return to exit the function at any point, not just at the end.

# %%
def check_number(n):
  if n>0:
    return "Positive"
    return "Non-positive"

    print(check_number(-1))

# %% [markdown]
# #5. What are iterators in Python and how do they differ from iterables?
# -   Iterables and iterators are closely related in Python, but they serve different roles. Which is shown below
# # Iterable
# - An iterable is any object that can return an iterator. It has a          buit-in_iter_() method.

# %%
#Examples:lists,tuples,strings,sets,dictionaries
my_list=[1,2,3] # This is iterable

# %% [markdown]
# # Iterator
# -An iterator is an object that represents a stream of data and knows how to get the next item. It impliments two methods:
# - 1.__iter_()- return the iterator itself
#
# - 2.__next__()- return the next item or raises Stopiteration when done

# %%
my_iter=iter(my_list) # This is an iterator
print(next(my_iter)) #1
print(next(my_iter)) #2

# %% [markdown]
# #6.Explain the concept of generators in Python and how they are defined.
# - Concept:
# Generators in Python are a simple and powerful way to create iterators using a function-like syntax.
# They allow we to yield values one at a time, which is very memory -efficient-perfect for working with large datasets or streams of data.
# # Definition of Generators:
#    -A generator is a function that contains yield instead of return. It pause after each yield, keeping its state, and resumes when you call next() again.

# %%
# Defining of Generators

def count_up_to(n):
  count = 0
  while count<= n:
    yield count
    count+=1

    # Calling this function doesn't execute it immediately - it returns a generator object:

# %% [markdown]
# # Using Generators in a for Loops
#   Generators are often used in for loops:

# %%
# prompt: generators in a for loop

def count_up_to(n):
  count = 0
  while count <= n:
    yield count
    count += 1

for number in count_up_to(5):
number

# %% [markdown]
# #7.What are the advantages of using generators over regular functions?
# - Generators in Python offer several advantages over regular functions, especially when dealing with large datasets  or resourse-intensive operations. Here are the key benifits:
# #1. Memory Efficiency
# - Generators yield ones at atime using yield, so they don't store the entire sequence in memory.
# - Regular functions (that return lists) build and store the full result in memory, which can be inefficient for large date.

# %%
#Example
def gen_nums():
  for i in range(10000):
    yield i

# %%
#This uses almost no memory compared to:

def list_nums():
  return [i for i in range(10000)]

# %% [markdown]
# #2. Infinite Sequences
#  Generators can model infinite data streams or sequences, since they don't try store everything at once.

# %%
from re import I
def count_up():
  i=0
  while True:
    yield i
    i+=1

# %% [markdown]
# #3.Lazy Evaluation
# - Generators produce items only when requested (on-the-fly).
# - This means no computation is done until you iterate over the generator, saving time and resources.
#
# # These are the advantages of using generators over regular functions.

# %% [markdown]
# #8.What is the lambda function in Python and when is it typically used?
# - A lambda function in Python is a small, anonymous function defined using the lambda keyword instead of def. it can take any number of arguments but hs only one expression, which is evaluated and returned.

# %%
#Example
# Syntax
lambda arguments: expression

# %%
#Example
add=lambda x,y:x+y
print(add(3,5))

# %% [markdown]
# # Typical Uses:
#  Lambda functions are often used in places where you need a short, throwaway function, usually as an argument to higher-order functions like:
#  - map()
#  - filter()
#  - reduce() (from functions)
#  -sorted()

# %%
# Example of map()
numbers=[1,2,3]
squared=list(map(lambda x:x**2,numbers))
 print(squared)

# %%
# Example of With filter():
numbers=[1,2,3,4]
evens=list(filter(lambda x:x%2==0,numbers))

# %%
# Examples With sorted() (custom sort):
names=['Alice','Bob','charlie']
sorted_names=sorted(names,key=lambda x:len(x))

# %% [markdown]
# #9.Explain the purpose and usage of the 'map()' function in Python.
# -The map() function in Python is used to apply a function to every item in an iterable (like a list or tuple) and returns a new iterable (a map object) with the results.

# %%
#Example
map(function,iterable)

# %% [markdown]
# - function: a function to apply to each element.
# - iterable: a sequence (like list, tuple,etc.) whose elements the function will be applied to.

# %%
#example:
numbers=[1,2,3,4]
squared=list(map(lambda x:x**2,numbers))
print(squared)

# %% [markdown]
# # When to Use map():
# - When we want to transform all items in a sequence using the operation.
# -It's more concise and often faster than using a for loop.

# %% [markdown]
# #10.What is the difference between map(),reduce(),and filter() functions in Python?
# #1.map():
# - Purpose: Applies a function to every item in an iterable.
# - Returns: A map object (which can be converted to a list or another iterable).
# - Syntax: map(function,iterable)

# %%
nums=[1,2,3,4]
squared=list(map(lambda x:x**2,nums))

# %% [markdown]
# #2.Filters()
# - *Purpose:*
# Filters elements from an iterable for which the function returns True.
# - *Returns:* A filter object (convertible to a list,etc.).
# -*Syntax:* filter(function,iterable)

# %%
nums=[1,2,3,4]
even=filter(lambda x:x%2==0,nums)
print(list(even)) #[2,4]

# %% [markdown]
# #3.reduce()
# - *Purpose:* Applies a rolling computation to sequential pairs of values in an iterable.
# - *Return:* A single value.
# - *Syntax:* reduce(function,iterable)

# %%
from functools import reduce
nums=[1,2,3,4]
sum_all=reduce(lambda x,y:x+y,nums)
print(sum_all) #10

# %% [markdown]
# #11.Using pen & paper write internal mechanism for sum operation using reduce function on this given list:[47,11,42,13];
# (Attach paper image for this answer) in doc or colab notebook.

# %% [markdown]
# -![DocScanner 04-Apr-2025 3-41 pm.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Practical Questions:

# %% [markdown]
# #1. Write a python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
# Here is the code of that given question
def sum_even_numbers(numbers):
    sum = 0
    for num in numbers:
        if num % 2 == 0:
            sum += num
    return sum

# %%
#Example usage
numbers=[1,2,3,4,5,6,7,8]
print(sum_even_numbers(numbers))

# %% [markdown]
# #2.Create a Python function that accepts a string and returns the reverse of that string.
# -

# %%
#definition
def reverse_string(s):
  return s[::-1]

# %%
#Example
text="Hello World"
print(reverse_string(text))

# %% [markdown]
# #3.Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
#Definition
def square_numbers(number)
return [num**2 for num in numbers]

# %%
#Example
numbers=[1,2,3,4,5]
print(square_numbers(numbers))

# %% [markdown]
# #4.Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
#Definition
def is_prime(n):
  if n<2:
    return False
    for i in range(2,int(n**0.5)+1):
      if n%i==0:
        return False
        return True

# %%
# Example
prime_numbers=[num for num in range(1,200) if is_prime(num)]
print(prime_numbers)

# %% [markdown]
# #5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
# Definition
 class Fibonacciterator:
  def__init__(self,n_terms):
    self.n_terms=n_terms
    self.a, self.b=0,1
    self.count=0

    def __iter__(self):
      return self
      def __next__(self):
        if self.count>=self.n_terms:
          raise StopIteration
          fib_number=self.a
          self.a, self.b=self.b, self.a+self.b
          self.count+=1
          return fib_number

# %%
#Example
fib_iter=Fibonacciterator(11)
for num in fib_iter:
  print(num)

# %% [markdown]
# #6.Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
#Definition
 def powers_of_two(max_exponent):
  for exponent in range (max_exponent+1):
    yield 2**exponent

# %%
# Example
for power in powers_of_two(6):
  print(power,end="")

# %% [markdown]
# #7.Impliment a generator function that reads a file line by line and yields each as a string.

# %%
# Definition
def read_file_line_by_line(file_path):
  with open(file_path,'r', encoding='utf-8') as file:
    for line in file:
      yield line.strip() # Remove leading/trailing whitespace

# %%
#Example
file_path="example.txt"
for line in read_file_line_by_line(file_path):
  print(line)

# %% [markdown]
# #8.Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
#Example
# list of tuple
tuples_list = [(1,3), (4,1), (2,7), (5,9)]

# Sorting based on the second element of each tuple
sorted_list = sorted(tuples_list, key=lambda x: x[1])
print(sorted_list)

#Output the sorted list
print(sorted_list)

# %% [markdown]
# #9. Write a Python program that uses map() to convert a list of temperatures from Celcius to Fahrenheit.

# %%
# Function to convert Celcius to Fahrenheit
def celcius_to_fahrenheit(celcius):
  return (celcius*9/5)+32

  # List of temperatures in Celcius
  celcius_temperatures=[25,30,35,40]

  # Use map() to apply the conversion function to each temperature
  fahrenheit_temperatures=list(map(celcius_to_fahrenheit,celcius_temperatures))

  # Print the converted temperatures
  for fahrenheit_temperature in fahrenheit_temperatures:
    print(fahrenheit_temperature)

# %% [markdown]
# #10.Create a Python program that uses filter() to remove all the vowels from a given string.

# %%
#Definition
 def remove_vowels(s):
  vowels="aeiouAEIOU"
  return"".join(filter(lambda char: char not in vowels,s))

# %%
#Example
text="Hello,World!"
result=remove_vowels(text)
print(result)

# %% [markdown]
# #11.Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# _ ![DocScanner 04-Apr-2025 5-24 pm.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Write a Python program, Which returns a list with 2-tuples. Each tuples consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,euro if the value of the order is smaller than 100,00 euro.
#
# Write a Python programme using lambda and map.

# %%
#List of orders, where each sublist contains:
#[Orders Numbers, Book Title and Author, Quantity,Price per Item]
Orders=[
    [34587,"Learning Pythonb,Mark Lutz", 4,40.95],
    [98762,"Programming Python,Mark Lutz",5,56.80],
    [77226,"Head First Python,Paul Barry",3,32.95],
[88112,"Einfuhrung in Python3,Bernd Klein", 3,24.99]
]

# Using Lambda and map to process the list and calculate the totals
result=list(map(lambda order: (order[0], (order[2]*order[3] + 10 if order[2]*order[3]<100 else order[2]*order[3],2)] if order[2]*order[3]<
 # Output the result
                               print(result)

# %% [markdown]
# ## Today i've some problem in my colab no program run today . I've facing a lot of problems to run my programms.
# But no program run till now.
# # Sorry
# So i'm going to submit this assignment without run the programmes.
